# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("mental_health.csv")
df6 = pd.read_csv("notself_employed 1.csv")

# %%
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                  6-25
# 2                                                  6-25
# 3                                                   NaN
# 4                                                  6-25
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...

# %%
len(df) #row number
# Out:
# 1433

# %%
len(df.columns) #attribute number
# Out:
# 63

# %%
print(df.columns)
# Out:
# Index(['Are you self-employed?',
#        'How many employees does your company or organization have?',
#        'Is your employer primarily a tech company/organization?',
#        'Is your primary role within your company related to tech/IT?',
#        'Does your employer provide mental health benefits as part of healthcare coverage?',
#        'Do you know the options for mental health care available under your employer-provided coverage?',
#        'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#        'Does your employer offer resources to learn more about mental health concerns and options for seeking help?',
#        'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#        'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
# ...

# %%
df1=df.isnull()
#       'Do you currently have a mental health disorder?',

# %%
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                  6-25
# 2                                                  6-25
# 3                                                   NaN
# 4                                                  6-25
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...

# %%
df1
# Out:
#       Are you self-employed?  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 1428                   False
# 1429                   False
# 1430                   False
# 1431                   False
# 1432                   False
#
#       How many employees does your company or organization have?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 1428                                               True
# 1429                                               True
# 1430                                              False
# ...

# %%
ncount=0
nncount=0
for index, row in df1.iterrows():
    if index:
        ncount+=1      
ncount
# Out:
# 1432

# %%
ncount=0
for i in range(len(df1)):
    for j in range(len(df1.columns)):
        if df1.iloc[i,j]== True:
            ncount+=1
            
ncount
# Out:
# 21960

# %%
df6
# Out:
#       Unnamed: 0  How many employees does your company or organization have?  \
# 0              0                                                  3
# 1              1                                                  2
# 2              2                                                  2
# 3              4                                                  2
# 4              5                                                  6
# ...          ...                                                ...
# 1141        1426                                                  4
# 1142        1427                                                  5
# 1143        1430                                                  4
# 1144        1431                                                  4
# 1145        1432                                                  4
#
#       Is your employer primarily a tech company/organization?  \
# 0                                                     1
# ...

# %%
for data in df6:
 print(data)
# Out:
# Unnamed: 0
# How many employees does your company or organization have?
# Is your employer primarily a tech company/organization?
# Does your employer provide mental health benefits as part of healthcare coverage?
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?
# Does your employer offer resources to learn more about mental health concerns and options for seeking help?
# Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?
# If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:
# Do you think that discussing a mental health disorder with your employer would have negative consequences?
# Do you think that discussing a physical health issue with your employer would have negative consequences?
# ...

# %%
df["What is your age?"].describe()
# Out:
# count    1433.000000
# mean       34.286113
# std        11.290931
# min         3.000000
# 25%        28.000000
# 50%        33.000000
# 75%        39.000000
# max       323.000000
# Name: What is your age?, dtype: float64

# %%
df["What is your age?"].describe()

# %%
boxplot=df6.boxplot(column=['How many employees does your company or organization have?'])

# %%
boxplot=df6.boxplot(column=['What is your age?'])

# %%
df6.plot(kind = 'hist', x = 'Is your employer primarily a tech company/organization?',
         y = 'Do you currently have a mental health disorder?')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df6['Is your employer primarily a tech company/organization?'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Is your employer primarily a tech company/organization?'>

# %%
df6['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Does your employer provide mental health benefits as part of healthcare coverage?'>

# %%
df6['Do you think that discussing a mental health disorder with your employer would have negative consequences?'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Do you think that discussing a mental health disorder with your employer would have negative consequences?'>

# %%
df6['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts().plot(kind='pie')

# %%
df6['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts().plot(kind='pie')

# %%
df6['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts().plot(kind='pie')
